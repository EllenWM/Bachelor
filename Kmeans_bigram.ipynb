# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
sns.set_theme()
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [20, 10]
sns.set_theme()
sns.set_style("whitegrid")
sns.set_context("poster", font_scale = 1.2)

# %%
os.chdir("/Users/Ellen/Documents/Dokumenter/DTU/7. Semester/Bachelor/CSV files")

pSelect = pd.read_csv('pSelect.csv') #pmatrix with the selected stop types
StopList = pd.read_csv('StopList.csv')
df = pd.read_csv('gapSelect.csv', header=None).rename(columns={0: 'clusterCount', 1: 'gap', 2: 's_k', 3: 'gap-s_k', 4: 'wss'})

os.chdir("/Users/Ellen/Documents/Dokumenter/DTU/7. Semester/Bachelor")

data = pd.read_csv("dataWNames.csv") #data

# %%
df
# Out:
#     clusterCount       gap       s_k   gap-s_k           wss
# 0            1.0  1.927405  0.001195  1.926211  10473.788098
# 1            2.0  2.324277  0.000944  2.323333   6474.207873
# 2            3.0  2.562590  0.000796  2.561795   4826.973117
# 3            4.0  2.670675  0.000882  2.669793   4137.515144
# 4            5.0  2.751402  0.000735  2.750668   3681.021620
# 5            6.0  2.811933  0.000704  2.811229   3358.398046
# 6            7.0  2.866536  0.000701  2.865834   3101.649231
# 7            8.0  2.908810  0.000928  2.907882   2898.919659
# 8            9.0  2.936049  0.000606  2.935443   2758.680070
# 9           10.0  2.954453  0.001057  2.953396   2648.427337
# 10          11.0  2.979452  0.000880  2.978572   2548.494530
# 11          12.0  3.000461  0.000800  2.999661   2459.319711
# 12          13.0  3.019605  0.000866  3.018738   2382.443485
# 13          14.0  3.037068  0.000663  3.036405   2308.280139
# 14          15.0  3.053184  0.000846  3.052338   2238.731584
# 15          16.0  3.066058  0.000850  3.065208   2176.052668
# 16          17.0  3.077500  0.000809  3.076691   2132.057189
# 17          18.0  3.090153  0.000740  3.089414   2085.980806
# 18          19.0  3.101713  0.000699  3.101015   2045.600592
# 19          20.0  3.115745  0.000831  3.114914   2002.413242
# 20          21.0  3.125946  0.000867  3.125079   1967.923294
# 21          22.0  3.134654  0.000841  3.133812   1935.608426
# 22          23.0  3.146441  0.000525  3.145916   1899.976735
# 23          24.0  3.150760  0.001065  3.149695   1879.462000
# 24          25.0  3.162853  0.001200  3.161653   1843.687705
# 25          26.0  3.171576  0.000653  3.170923   1815.797708
# 26          27.0  3.180433  0.000862  3.179571   1788.261545
# 27          28.0  3.192772  0.000679  3.192093   1756.357769
# 28          29.0  3.199256  0.000870  3.198386   1733.221458
# 29          30.0  3.204697  0.001121  3.203576   1711.904344
# 30          31.0  3.209325  0.000865  3.208461   1692.256369
# 31          32.0  3.213454  0.001063  3.212391   1672.681957
# 32          33.0  3.218807  0.000941  3.217866   1655.199089
# 33          34.0  3.229395  0.000869  3.228526   1629.687429
# 34          35.0  3.236364  0.001032  3.235332   1611.203897
# 35          36.0  3.244967  0.000830  3.244136   1590.646244
# 36          37.0  3.249472  0.001018  3.248454   1576.346794
# 37          38.0  3.258704  0.001047  3.257657   1555.120646
# 38          39.0  3.260576  0.000803  3.259773   1546.370337
# 39          40.0  3.271986  0.000945  3.271042   1522.477543
# 40          41.0  3.277128  0.000741  3.276386   1509.218992
# 41          42.0  3.281400  0.000957  3.280443   1497.319164
# 42          43.0  3.287380  0.000769  3.286611   1482.817489
# 43          44.0  3.292462  0.000423  3.292038   1469.761128
# 44          45.0  3.296798  0.000664  3.296134   1458.473340
# 45          46.0  3.299511  0.000790  3.298721   1449.518713
# 46          47.0  3.303327  0.000767  3.302560   1438.711905
# 47          48.0  3.309734  0.000859  3.308875   1424.933215
# 48          49.0  3.313136  0.000901  3.312235   1415.189208
# 49          50.0  3.319639  0.000859  3.318780   1401.292687
# 50          51.0  3.317160  0.000854  3.316306   1400.495773
# 51          52.0  3.328617  0.001073  3.327545   1380.475394
# 52          53.0  3.329832  0.001201  3.328630   1374.670489
# 53          54.0  3.335357  0.000958  3.334398   1362.612050
# 54          55.0  3.340975  0.000709  3.340267   1351.028931
# 55          56.0  3.341398  0.000847  3.340551   1346.425766
# 56          57.0  3.345186  0.001151  3.344035   1336.912395
# 57          58.0  3.348655  0.001003  3.347653   1328.898154
# 58          59.0  3.353243  0.000905  3.352338   1318.834215
# 59          60.0  3.357539  0.001003  3.356537   1309.348855

# %%
os.chdir("/Users/Ellen/Documents/Dokumenter/DTU/7. Semester/Bachelor/Plots")

# %%
plt.plot(df['clusterCount'], df['gap'], linestyle='--', marker='o', color='b');
plt.xlabel('K');
plt.ylabel('Gap Statistic');
plt.savefig('gapStat.png', bbox_inches='tight')

# %%
#find the number of clusters, where gap(k) >= gap(k+1)-s_k
cluster = []
for i in range(df.shape[0]-1):
    if df['gap'][i] >= df['gap-s_k'][i+1]:
        #cluster.append(i)
        cluster.append(i+1)
        
cluster
# Out:
# [50, 55]

# %%
#p-matrix w. selected cat
pSel = pSelect.to_numpy()

# %%
#number of clusters
K = cluster[0]

# %%
#Kmeans with the found number of clusters found with gap statistic
Kmean = KMeans(n_clusters=K, random_state = 1243)

# %%
Kmean.fit(pSel)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=50, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=1243, tol=0.0001, verbose=0)

# %%
centroid = Kmean.cluster_centers_

# %%
#Check if shape is right
np.shape(centroid)
# Out:
# (50, 13)

# %%
os.chdir("/Users/Ellen/Documents/Dokumenter/DTU/7. Semester/Bachelor/CSV files")

#save centroid
pd.DataFrame(centroid).to_csv('centroid.csv', index = False)

# %%
#label of each user
label = Kmean.labels_

# %%
#save label
pd.DataFrame(label).to_csv('labels.csv', index = False)

# %%
#create array for each cluster with index of users
for i in range(0,K):
    exec(f'c{i} = np.where(label == i)')

# %%
#create array with the probability for each element in each cluster
for i in range(0,K):
    exec(f'prob{i} = pSel[c{i}]')

# %%
#make matrix, with axis 0 = length of StopList(number of selected Stops). axis 1 = number of clusters
avg = np.zeros((len(StopList),K))

# %%
for j in range(0,K):
    for i in range(0, len(StopList)):
        exec(f'avg[i,j] = np.sum(prob{j}[:,i]) / np.shape(prob{j})[0]') #avg (sum of prob for each stop / number of users)

# %%
pd.DataFrame(avg).to_csv('avg.csv', index = False)

# %%
os.chdir("/Users/Ellen/Documents/Dokumenter/DTU/7. Semester/Bachelor/Plots")

# %%
#heatmap without log
ax = sns.heatmap(avg, cmap="BuPu")
ax.set_yticklabels(StopList.Stop.tolist())
plt.setp(ax.get_yticklabels(), rotation=0, ha="right",
             rotation_mode="anchor")
plt.xlabel('Clusters', fontsize = 18)
plt.savefig('KmeanheatmapBigram.png', bbox_inches='tight') #save plot
plt.show()

# %%
#heatmap with log
ax = sns.heatmap(np.log(avg), cmap="BuPu")
ax.set_yticklabels(StopList.Stop.tolist())
plt.setp(ax.get_yticklabels(), rotation=0, ha="right",
             rotation_mode="anchor")
plt.xlabel('Clusters', fontsize = 14)
plt.savefig('KmeanheatmapBigramLog.png', bbox_inches='tight') #save plot
plt.show()
