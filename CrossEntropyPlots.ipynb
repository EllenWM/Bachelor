# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [20, 10]
import numpy as np
sns.set_theme()
sns.set_style("whitegrid")
sns.set_context("poster", font_scale = 1.2)

# %%
#load of entropy files
os.chdir("/Users/Ellen/Documents/Dokumenter/DTU/7. Semester/Bachelor/CSV files")

CrossEntropy_cat = pd.read_csv("CrossEntropyCat.csv")
CrossEntropy_ID = pd.read_csv("CrossEntropyID.csv")

entropy_cat = pd.read_csv("entropyBigram.csv")
entropy_ID = pd.read_csv("entropy_stopID.csv")

# %%
colors = ["#C54E57", "#65ab7c"] #dull red, tea, cornflower blue
sns.set_palette(sns.color_palette(colors))

# %%
CrossEntropy_cat
# Out:
#        Cross-Entropy
# 0           3.251473
# 1           2.225523
# 2           2.794593
# 3           4.046411
# 4           3.385124
# ...              ...
# 92719       2.387666
# 92720       1.603419
# 92721       1.657267
# 92722       3.622642
# 92723       1.724467
#
# [92724 rows x 1 columns]

# %%
os.chdir("/Users/Ellen/Documents/Dokumenter/DTU/7. Semester/Bachelor/Plots")

sns.histplot(data=CrossEntropy_cat)
sns.histplot(data=CrossEntropy_ID['Cross-Entropy'],color = 'cornflowerblue')
plt.legend(loc='upper left', labels=['stop subcategory', 'stop ID'])
plt.xlabel('Cross-Entropy')
plt.ylabel('Number of users')
plt.savefig('CrossEntropy.png', bbox_inches='tight')
plt.show()

# %%
#median
print(np.median(CrossEntropy_cat))
print(np.median(CrossEntropy_ID))
# Out:
# 2.5895483769756162
# 2.829230690128983

# %%
#max
print(max(CrossEntropy_cat['Cross-Entropy']))
print(max(CrossEntropy_ID['Cross-Entropy']))
# Out:
# 7.365910799707263
# 7.388529724614707

# %%
sns.histplot(data=entropy_cat['s_actual'])
sns.histplot(data=CrossEntropy_cat['Cross-Entropy'], color = 'cornflowerblue')
plt.legend(loc='upper left', labels=['Entropy', 'Cross-Entropy'])
plt.xlabel('Entropy')
plt.ylabel('Number of users')
plt.savefig('entropyVSCrossEntropyCat.png', bbox_inches='tight')
plt.show()

# %%
#median
print(np.median(entropy_cat['s_actual']))
print(np.median(CrossEntropy_cat))
# Out:
# 2.043672925884689
# 2.5895483769756162

# %%
#max
print(max(entropy_cat['s_actual']))
print(max(CrossEntropy_cat['Cross-Entropy']))
# Out:
# 3.986748447394189
# 7.365910799707263

# %%
sns.histplot(data=entropy_ID['s_actual'])
sns.histplot(data=CrossEntropy_ID['Cross-Entropy'], color = 'cornflowerblue')
plt.legend(loc='upper left', labels=['Entropy', 'Cross-Entropy'])
plt.xlabel('Entropy')
plt.ylabel('Number of users')
plt.savefig('entropyVSCrossEntropyID.png', bbox_inches='tight')
plt.show()

# %%
#median
print(np.median(entropy_ID['s_actual']))
print(np.median(CrossEntropy_ID))
# Out:
# 2.1504983034321894
# 2.829230690128983

# %%
#max
print(max(entropy_ID['s_actual']))
print(max(CrossEntropy_ID['Cross-Entropy']))
# Out:
# 5.426876859005861
# 7.388529724614707
